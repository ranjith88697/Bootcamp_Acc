# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjith88697/Bootcamp_Acc/blob/main/Day9_Pinecone_vector_database_practical_tasks_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Mastering the Pinecone vector database.**

# %% [markdown]
# ##**GOAL: save text sentence embeddings and perform semantic search in Pinecone using Python code.**

# %% [markdown]
# Create a Pinecone Account: Head to 'Pinecone.io' and sign up for a free account. After signing up, you’ll be given an API key.

# %% [markdown]
#  To start working with Pinecone,
# install 'pinecone' library

# %%
pip install pinecone
# Out:
# Collecting pinecone
#   Downloading pinecone-8.0.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.12/dist-packages (from pinecone) (2026.1.4)
# Requirement already satisfied: orjson>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from pinecone) (3.11.7)
# Collecting pinecone-plugin-assistant<4.0.0,>=3.0.1 (from pinecone)
#   Downloading pinecone_plugin_assistant-3.0.2-py3-none-any.whl.metadata (30 kB)
# Collecting pinecone-plugin-interface<0.1.0,>=0.0.7 (from pinecone)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from pinecone) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.12/dist-packages (from pinecone) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.12/dist-packages (from pinecone) (2.5.0)
# Collecting packaging<25.0,>=24.2 (from pinecone-plugin-assistant<4.0.0,>=3.0.1->pinecone)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from pinecone-plugin-assistant<4.0.0,>=3.0.1->pinecone) (2.32.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<4.0.0,>=3.0.1->pinecone) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<4.0.0,>=3.0.1->pinecone) (3.11)
# Downloading pinecone-8.0.1-py3-none-any.whl (736 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 736.8/736.8 kB 6.5 MB/s eta 0:00:00
# Downloading pinecone_plugin_assistant-3.0.2-py3-none-any.whl (280 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.9/280.9 kB 12.8 MB/s eta 0:00:00
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: pinecone-plugin-interface, packaging, pinecone-plugin-assistant, pinecone
#   Attempting uninstall: packaging
#     Found existing installation: packaging 26.0
#     Uninstalling packaging-26.0:
#       Successfully uninstalled packaging-26.0
# Successfully installed packaging-24.2 pinecone-8.0.1 pinecone-plugin-assistant-3.0.2 pinecone-plugin-interface-0.0.7

# %% [markdown]
# From 'pinecone' library import Pinecone, ServerlessSpec.

# %%
from pinecone import Pinecone, ServerlessSpec

# %% [markdown]
# On the Pinecone main page, navigate to the "Get started" section via the left menu. Next, follow the "Quick Start for Developers" guide.
# * Initialaze a client.
# * Create an index.
# * Upsert data.
# * Perform a search.

# %% [markdown]
# When you perform "Upsert data", add a list of your own text strings.

# %% [markdown]
# When you perform "Search", use of your own text string.

# %%
from pinecone import Pinecone, ServerlessSpec

pc = Pinecone(api_key="###################################")

# %%
index_name = "developer-quickstart-py"

if not pc.has_index(index_name):
    pc.create_index_for_model(
        name=index_name,
        cloud="aws",
        region="us-east-1",
        embed={
            "model":"llama-text-embed-v2",
            "field_map":{"text": "chunk_text"}
        }
    )

# %%
index = pc.Index(index_name)

records = [
    { "_id": "rec1", "chunk_text": "The Eiffel Tower was completed in 1889 and stands in Paris, France.", "category": "history" },
    { "_id": "rec2", "chunk_text": "Photosynthesis allows plants to convert sunlight into energy.", "category": "science" },
    { "_id": "rec3", "chunk_text": "Albert Einstein developed the theory of relativity.", "category": "science" },
    { "_id": "rec4", "chunk_text": "The mitochondrion is often called the powerhouse of the cell.", "category": "biology" },
    { "_id": "rec5", "chunk_text": "Shakespeare wrote many famous plays, including Hamlet and Macbeth.", "category": "literature" },
    { "_id": "rec6", "chunk_text": "Water boils at 100°C under standard atmospheric pressure.", "category": "physics" },
    { "_id": "rec7", "chunk_text": "The Great Wall of China was built to protect against invasions.", "category": "history" },
    { "_id": "rec8", "chunk_text": "Honey never spoils due to its low moisture content and acidity.", "category": "food science" },
    { "_id": "rec9", "chunk_text": "The speed of light in a vacuum is approximately 299,792 km/s.", "category": "physics" },
    { "_id": "rec10", "chunk_text": "Python is the easiest language of history.", "category": "programming" }
]

index.upsert_records("ns1", records)
# Out:
# UpsertResponse(upserted_count=10, _response_info={'raw_headers': {'date': 'Thu, 19 Feb 2026 13:48:04 GMT', 'content-length': '0', 'connection': 'keep-alive', 'x-pinecone-request-lsn': '1', 'x-pinecone-api-version': '2025-10', 'x-envoy-upstream-service-time': '465', 'x-pinecone-response-duration-ms': '466', 'server': 'envoy'}})

# %%
print(index.describe_index_stats())
# Out:
# {'_response_info': {'raw_headers': {'connection': 'keep-alive',
#                                     'content-length': '176',
#                                     'content-type': 'application/json',
#                                     'date': 'Thu, 19 Feb 2026 13:48:33 GMT',
#                                     'grpc-status': '0',
#                                     'server': 'envoy',
#                                     'x-envoy-upstream-service-time': '52',
#                                     'x-pinecone-request-latency-ms': '51',
#                                     'x-pinecone-response-duration-ms': '54'}},
#  'dimension': 1024,
#  'index_fullness': 0.0,
#  'memoryFullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'ns1': {'vector_count': 10}},
#  'storageFullness': 0.0,
#  'total_vector_count': 10,
#  'vector_type': 'dense'}

# %%
query = "Python is a programming language"

results = index.search(
    namespace="ns1",
    query={
        "top_k": 5,
        "inputs": {
            'text': query
        }
    }
)
# Out:
# {'_response_info': {'raw_headers': {'connection': 'keep-alive',
#                                     'content-length': '812',
#                                     'content-type': 'application/json',
#                                     'date': 'Thu, 19 Feb 2026 13:53:03 GMT',
#                                     'server': 'envoy',
#                                     'x-envoy-upstream-service-time': '161',
#                                     'x-pinecone-api-version': '2025-10',
#                                     'x-pinecone-max-indexed-lsn': '1',
#                                     'x-pinecone-response-duration-ms': '162'}},
#  'result': {'hits': [{'_id': 'rec10',
#                       '_score': 0.47375574707984924,
#                       'fields': {'category': 'programming',
#                                  'chunk_text': 'Python is the easiest language '
#                                                'of history.'}},
#                      {'_id': 'rec2',
#                       '_score': 0.11649515479803085,
#                       'fields': {'category': 'science',
#                                  'chunk_text': 'Photosynthesis allows plants '
#                                                'to convert sunlight into '
#                                                'energy.'}},
#                      {'_id': 'rec4',
#                       '_score': 0.10189759731292725,
#                       'fields': {'category': 'biology',
#                                  'chunk_text': 'The mitochondrion is often '
#                                                'called the powerhouse of the '
#                                                'cell.'}},
#                      {'_id': 'rec7',
#                       '_score': 0.09056594222784042,
#                       'fields': {'category': 'history',
#                                  'chunk_text': 'The Great Wall of China was '
#                                                'built to protect against '
#                                                'invasions.'}},
#                      {'_id': 'rec3',
#                       '_score': 0.08540280908346176,
#                       'fields': {'category': 'science',
#                                  'chunk_text': 'Albert Einstein developed the '
#                                                'theory of relativity.'}}]},
#  'usage': {'embed_total_tokens': 8, 'read_units': 1}}

# %% [markdown]
# Print search results.

# %%
print(results)
# Out:
# {'_response_info': {'raw_headers': {'connection': 'keep-alive',
#                                     'content-length': '812',
#                                     'content-type': 'application/json',
#                                     'date': 'Thu, 19 Feb 2026 13:53:03 GMT',
#                                     'server': 'envoy',
#                                     'x-envoy-upstream-service-time': '161',
#                                     'x-pinecone-api-version': '2025-10',
#                                     'x-pinecone-max-indexed-lsn': '1',
#                                     'x-pinecone-response-duration-ms': '162'}},
#  'result': {'hits': [{'_id': 'rec10',
#                       '_score': 0.47375574707984924,
#                       'fields': {'category': 'programming',
#                                  'chunk_text': 'Python is the easiest language '
#                                                'of history.'}},
#                      {'_id': 'rec2',
#                       '_score': 0.11649515479803085,
#                       'fields': {'category': 'science',
#                                  'chunk_text': 'Photosynthesis allows plants '
#                                                'to convert sunlight into '
#                                                'energy.'}},
#                      {'_id': 'rec4',
#                       '_score': 0.10189759731292725,
#                       'fields': {'category': 'biology',
#                                  'chunk_text': 'The mitochondrion is often '
#                                                'called the powerhouse of the '
#                                                'cell.'}},
#                      {'_id': 'rec7',
#                       '_score': 0.09056594222784042,
#                       'fields': {'category': 'history',
#                                  'chunk_text': 'The Great Wall of China was '
#                                                'built to protect against '
#                                                'invasions.'}},
#                      {'_id': 'rec3',
#                       '_score': 0.08540280908346176,
#                       'fields': {'category': 'science',
#                                  'chunk_text': 'Albert Einstein developed the '
#                                                'theory of relativity.'}}]},
#  'usage': {'embed_total_tokens': 8, 'read_units': 1}}

# %%
reranked_results = index.search(
    namespace="ns1",
    query={
        "top_k": 5,
        "inputs": {
            'text': query
        }
    },
    rerank={
        "model": "bge-reranker-v2-m3",
        "top_n": 5,
        "rank_fields": ["chunk_text"]
    },
    fields=["category", "chunk_text"]
)

print(reranked_results)
# Out:
# {'_response_info': {'raw_headers': {'connection': 'keep-alive',
#                                     'content-length': '845',
#                                     'content-type': 'application/json',
#                                     'date': 'Thu, 19 Feb 2026 13:53:41 GMT',
#                                     'server': 'envoy',
#                                     'x-envoy-upstream-service-time': '388',
#                                     'x-pinecone-api-version': '2025-10',
#                                     'x-pinecone-max-indexed-lsn': '1',
#                                     'x-pinecone-response-duration-ms': '389'}},
#  'result': {'hits': [{'_id': 'rec10',
#                       '_score': 0.08772001415491104,
#                       'fields': {'category': 'programming',
#                                  'chunk_text': 'Python is the easiest language '
#                                                'of history.'}},
#                      {'_id': 'rec7',
#                       '_score': 1.7231572201126255e-05,
#                       'fields': {'category': 'history',
#                                  'chunk_text': 'The Great Wall of China was '
#                                                'built to protect against '
#                                                'invasions.'}},
#                      {'_id': 'rec4',
#                       '_score': 1.6964426322374493e-05,
#                       'fields': {'category': 'biology',
#                                  'chunk_text': 'The mitochondrion is often '
#                                                'called the powerhouse of the '
#                                                'cell.'}},
#                      {'_id': 'rec3',
#                       '_score': 1.6442494597868063e-05,
#                       'fields': {'category': 'science',
#                                  'chunk_text': 'Albert Einstein developed the '
#                                                'theory of relativity.'}},
#                      {'_id': 'rec2',
#                       '_score': 1.6187581422855146e-05,
#                       'fields': {'category': 'science',
#                                  'chunk_text': 'Photosynthesis allows plants '
#                                                'to convert sunlight into '
#                                                'energy.'}}]},
#  'usage': {'embed_total_tokens': 8, 'read_units': 1, 'rerank_units': 1}}
