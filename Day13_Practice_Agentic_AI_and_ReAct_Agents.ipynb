# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjith88697/Bootcamp_Acc/blob/main/Day13_Practice_Agentic_AI_and_ReAct_Agents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practice - Agentic AI and ReAct Agents
#
# ## What is ReAct? (Think of an AI Agent as a Person)
#
# **ReAct** = **Reason** + **Act**
#
# Imagine an AI agent like a person solving problems:
# - **🧠 Mind**: Uses reasoning to think and plan
# - **🛠️ Tools**: Interacts with the world to get things done
# - **👀 Senses**: Observes results from the world
# - **📝 Memory**: Remembers what it has learned
#
# The agent repeats this loop:
# 1. **Thought 🧠**: What should I do?
# 2. **Action 🛠️**: Use a tool to do it
# 3. **Observation 👀**: What happened?
# 4. **Memory 📝**: Remember what I learned
# 5. **Repeat** until task is done
#
# Let's learn by building.

# %% [markdown]
# ## PART 1: 🧠 Inside the Agent's Mind
#
# Watch how an AI agent **thinks, acts, observes, and remembers**—just like a person!
#
# ### **Example 1: Weather Question**
#
# **User Question:** "What's the weather in Paris and should I bring an umbrella?"
#
# **Agent's Tools 🛠️:**
# - `get_weather(city)` - A tool that retrieves weather data
#
# #### The Agent's Thought Loop:
#
# | Step | Part | What the Agent Does |
# |------|------|---------------------|
# | 1 | 🧠 **Thought** | "I need to answer two things: the weather AND umbrella advice. Let me use my tool to get weather data." |
# | 2 | 🛠️ **Action** | Uses tool `get_weather("Paris")` |
# | 3 | 👀 **Observation** | Gets the response: `"Paris: 15°C, Rainy"` |
# | 4 | 📝 **Memory** | Saves this as a memory: "Paris is 15°C and raining." |
# | 5 | 🧠 **Thought** | "Since it's raining, an umbrella is definitely needed. I have all the info for the answer now." |
# | 6 | ✅ **Answer** | "It's 15°C and rainy in Paris. Yes, you should bring an umbrella!" |

# %% [markdown]
# ### **Example 2: Multi-Step Question** (ReAct Cycle)
#
# **User Question:** "What's the capital of Japan and what's 2 + 2?"
#
# **Agent's Tools 🛠️:**
# - `get_capital(country)` - A tool that looks up capitals
# - `calculate(expression)` - A tool that does math
#
# **Key Insight:** The agent needs to use BOTH tools because there are TWO different questions!
#
# #### The Agent's Thought Loop:
#
# | Step | Part | What the Agent Does |
# |------|------|---------------------|
# | 1 | 🧠 **Thought** | "I notice this question asks for TWO different things: a capital and a calculation. I'll start with the capital." |
# | 2 | 🛠️ **Action** | Uses tool `get_capital("Japan")` |
# | 3 | 👀 **Observation** | Gets the response: `"Tokyo"` |
# | 4 | 📝 **Memory** | Saves "Japan's capital is Tokyo" to memory. |
# | 5 | 🧠 **Thought** | "Now I need to address the second part: the math problem." |
# | 6 | 🛠️ **Action** | Uses tool `calculate("2 + 2")` |
# | 7 | 👀 **Observation** | Gets the response: `"4"` |
# | 8 | 📝 **Memory** | Saves "2 + 2 equals 4" to memory. |
# | 9 | 🧠 **Thought** | "I have both pieces of information now. I can combine them for the final answer." |
# | 10 | ✅ **Answer** | "The capital of Japan is Tokyo and 2 + 2 is 4!" |
#
# **The ReAct Pattern:**
# Notice how we always follow: **Thought → Action → Observation → Memory**. If we aren't done, we start the cycle again with a new **Thought**!

# %% [markdown]
# ## PART 2: Tools - The Agent's Hands 🙌
#
# Tools are the core capabilities of an AI agent.
#
# Just like your hands let you interact with the world, **tools let agents interact with data, systems, and the internet.**

# %%
def add(a: float, b: float) -> float:
    return a + b


def multiply(a: float, b: float) -> float:
    return a * b


def divide(a: float, b: float) -> float | dict:
    if b == 0:
        return {"error": "Cannot divide by zero"}
    return a / b


# Test the tools
print("Agent testing its tools:")
print(f"Tool #1 (add): 5 + 3 = {add(5, 3)}")
print(f"Tool #2 (multiply): 4 * 6 = {multiply(4, 6)}")
print(f"Tool #3 (divide): 10 / 2 = {divide(10, 2)}")
print(f"Tool #3 error handling: 10 / 0 = {divide(10, 0)}")
# Out:
# Agent testing its tools:
# Tool #1 (add): 5 + 3 = 8
# Tool #2 (multiply): 4 * 6 = 24
# Tool #3 (divide): 10 / 2 = 5.0
# Tool #3 error handling: 10 / 0 = {'error': 'Cannot divide by zero'}

# %% [markdown]
# ### Exercise 1: Give the Agent a New Tool 🙌
#
# Create a new tool that does something useful. Examples:
# - Convert temperature (Celsius to Fahrenheit)
# - Calculate area of a rectangle
# - Get length of text
# - Check if a number is even or odd
#
# Design and test your new tool below:

# %%
# TODO: Create a tool of your choice below
# Example template:

def celsius_to_fahrenheit(c: float) -> float:
    """Convert Celsius to Fahrenheit."""
    return (c * 9/5) + 32

def rectangle_area(width: float, height: float) -> float:
    """Calculate the area of a rectangle."""
    return width * height

def text_length(text: str) -> int:
    """Return the number of characters in the text."""
    return len(text)

def is_even(number: int) -> str:
    """Return whether the given number is even or odd."""
    if number % 2 == 0:
        return f"{number} is even"
    return f"{number} is odd"

# Test your new tool:
print(f'Temperature in Fahrenheit of 0 celsius is {celsius_to_fahrenheit(0)}')
print(f'area of a rectangle for width-10 and height - 12 is {rectangle_area(10,12)}')
print(f'length of text Accenture is {text_length('Accenture')}')
print(is_even(5))   # -> "5 is odd"
print(is_even(10))  # -> "10 is even"





# Test your new tool:
# print(my_tool(5))
# Out:
# Temperature in Fahrenheit of 0 celsius is 32.0
# area of a rectangle for width-10 and height - 12 is 120
# length of text Accenture is 9
# 5 is odd
# 10 is even

# %% [markdown]
# ### Exercise 2: Build More Tools 🔧
#
# Now create **two** more tools:
# 1. **`subtract(a, b)`** — Subtracts b from a
# 2. **`power(base, exponent)`** — Raises base to the power of exponent (e.g., 2³ = 8)
#
# Make sure to test them with a few examples!

# %%
# TODO: Create a subtract tool
def subtract(a: float, b: float) -> float:
    """Tool: Subtract b from a."""
    return a - b


def power(base: float, exponent: float) -> float:
    """Tool: Raise base to the power of exponent."""
    return base ** exponent



# Test your tools:
print(f"10 - 3 = {subtract(10, 3)}")
print(f"2 ^ 8 = {power(2, 8)}")
print(f"5 ^ 0 = {power(5, 0)}")
# Out:
# 10 - 3 = 7
# 2 ^ 8 = 256
# 5 ^ 0 = 1

# %% [markdown]
# ### Exercise 2b: Build a Tool with Error Handling 🛡️
#
# Real-world tools need to handle **bad input** gracefully. An agent shouldn't crash — it should get a helpful error message and try something else.
#
# Create a `safe_divide(a, b)` tool that:
# - Returns `{"result": a / b}` when `b` is not zero
# - Returns `{"error": "Cannot divide by zero"}` when `b` is zero
#
# **Why does this matter for agents?** If a tool crashes, the entire ReAct loop breaks. Good error handling lets the agent **recover** and try a different approach.

# %%
# TODO: Create a safe_divide tool with proper error handling
def safe_divide(a: float, b: float) -> dict:
    """Divide a by b with error handling for division by zero."""
    if b == 0:
        return {"error": "Cannot divide by zero"}
    return {"result": a / b}



# Test cases — all should work without crashing:
print(safe_divide(10, 2))        # Expected: {"result": 5.0}
print(safe_divide(10, 0))        # Expected: {"error": "Cannot divide by zero"}
# Out:
# {'result': 5.0}
# {'error': 'Cannot divide by zero'}

# %% [markdown]
# ## PART 3: Memory - The Agent's Notebook 📝
#
# Now let's see an agent **Reason → Act → Observe → Remember → Repeat**.
#
# ### The ReAct Cycle (One Loop):
#
# | Step | Phase | What the Agent Does |
# |------|-------|---------------------|
# | 1 | 🧠 **Reason** | "What do I need to do? Which hand should I use?" |
# | 2 | 🙌 **Act** | Use a tool by calling it with the right input |
# | 3 | 👀 **Observe** | Get the result back from the tool |
# | 4 | 📝 **Remember** | Store what I learned: "The tool returned X" |
# | 5 | 🧠 **Reason Again** | "Do I have what I need, or do I need another tool?" |
#
# If the answer is "I need another tool" → Go back to **Act** (step 2)
# If the answer is "I'm done" → Give the **Final Answer** ✅

# %%
# Example: Agent's Thought Process with Memory

# Task: Calculate 25 * 4, then add 10 to the result
task = "Calculate 25 * 4, then add 10 to the result"
print(f"📋 Task: {task}\n")
print("=" * 60)

# --- STEP 1: Multiply 25 * 4 ---
thought = "I need two steps: multiply first, then add. Let me use my multiply tool."
print(f"🧠 Thought: {thought}")

# --- STEP 2: First Action (use multiply tool) ---
result1 = multiply(25, 4)
print("🙌 Action: Use multiply tool → multiply(25, 4)")

# --- STEP 3: First Observation ---
print(f"👀 Observation: Got {result1}")

# --- STEP 4: Memory Update ---
memory = f"Remember: 25 * 4 = {result1}"
print(f"📝 Memory: {memory}\n")


# --- TODO: CONTINUE TO IMPLEMENT THE NEXT STEPS ---
# TODO: Finish the second part of the loop!
# 1. 🧠 Thought: What do you need to do now?
# 2. 🙌 Action: Use the 'add' tool with result1 and 10
# 3. 👀 Observation: What is the result?
# 4. 📝 Memory: Update your final memory
# 5. ✅ Answer: Print the final answer

# YOUR CODE HERE:
# Task: Calculate 25 * 4, then add 10 to the result
task = "Calculate 25 * 4, then add 10 to the result"
print(f" Task: {task}\n")
print("=" * 60)

# --- STEP 1: Multiply 25 * 4 ---
thought = "I need two steps: multiply first, then add. Let me use my multiply tool."
print(f" Thought: {thought}")

# --- STEP 2: First Action (use multiply tool) ---
result1 = multiply(25, 4)
print(f" Action: Use multiply tool → multiply(25, 4)")

# --- STEP 3: Observe ---
print(f" Observation: The multiply tool returned {result1}")

# --- STEP 4: Remember ---
memory = {"step1_result": result1}
print(f" Memory updated: {memory}")

# --- STEP 5: Reason Again ---
thought2 = "Now I need to add 10 to the previous result. I'll use the add tool."
print(f" Thought: {thought2}")

# --- STEP 6: Second Action (use add tool) ---
result2 = add(memory["step1_result"], 10)
print(f" Action: Use add tool → add({memory['step1_result']}, 10)")

# --- STEP 7: Observe ---
print(f" Observation: The add tool returned {result2}")

# --- FINAL ANSWER ---
print("\n Final Answer:", result2)
# Out:
# 📋 Task: Calculate 25 * 4, then add 10 to the result
#
# ============================================================
# 🧠 Thought: I need two steps: multiply first, then add. Let me use my multiply tool.
# 🙌 Action: Use multiply tool → multiply(25, 4)
# 👀 Observation: Got 100
# 📝 Memory: Remember: 25 * 4 = 100
#
#  Task: Calculate 25 * 4, then add 10 to the result
#
# ============================================================
#  Thought: I need two steps: multiply first, then add. Let me use my multiply tool.
#  Action: Use multiply tool → multiply(25, 4)
#  Observation: The multiply tool returned 100
#  Memory updated: {'step1_result': 100}
#  Thought: Now I need to add 10 to the previous result. I'll use the add tool.
#  Action: Use add tool → add(100, 10)
#  Observation: The add tool returned 110
#
#  Final Answer: 110

# %% [markdown]
# ### Exercise 3: Complete a 3-Step ReAct Trace 🔄
#
# Now try a **harder** task that requires **three** tool calls!
#
# **Task:** *"Calculate (8 + 2) * 5, then subtract 15 from the result"*
#
# Steps needed:
# 1. 🙌 Use `add(8, 2)` → get 10
# 2. 🙌 Use `multiply(result, 5)` → get 50
# 3. 🙌 Use `subtract(result, 15)` → get 35
#
# Follow the same Thought → Action → Observation → Memory pattern for **all three** steps, then print the final answer.

# %%
# Exercise 3: 3-Step ReAct Trace
# Task: Calculate (8 + 2) * 5, then subtract 15 from the result

task = "Calculate (8 + 2) * 5, then subtract 15"
print(f"📋 Task: {task}\n")
print("=" * 60)

# Exercise 3: 3-Step ReAct Trace
# Task: Calculate (8 + 2) * 5, then subtract 15

task = "Calculate (8 + 2) * 5, then subtract 15"
print(f" Task: {task}\n")
print("=" * 60)

memory = {}

# --- STEP 1: Add ---
thought1 = "First I need to add 8 and 2 to get the initial value."
print(f" Thought: {thought1}")

result1 = add(8, 2)
print(" Action: Use add tool → add(8, 2)")
print(f" Observation: The add tool returned {result1}")

memory["step1"] = result1
print(f" Memory updated: {memory}\n")

# --- STEP 2: Multiply ---
thought2 = "Now I should multiply the previous result by 5."
print(f" Thought: {thought2}")

result2 = multiply(memory["step1"], 5)
print(f" Action: Use multiply tool → multiply({memory['step1']}, 5)")
print(f" Observation: The multiply tool returned {result2}")

memory["step2"] = result2
print(f" Memory updated: {memory}\n")

# --- STEP 3: Subtract ---
thought3 = "Finally, I subtract 15 from the last result."
print(f" Thought: {thought3}")

result3 = subtract(memory["step2"], 15)
print(f" Action: Use subtract tool → subtract({memory['step2']}, 15)")
print(f" Observation: The subtract tool returned {result3}")

memory["final"] = result3
print(f" Memory updated: {memory}\n")

# --- FINAL ANSWER ---
print(" Final Answer:", result3)


# TODO: Complete all 3 steps following the same pattern as the example above
# Each step needs: Thought → Action → Observation → Memory
# Step 1: Add
# Step 2: Multiply
# Step 3: Subtract
# Then print the final answer
# Out:
# 📋 Task: Calculate (8 + 2) * 5, then subtract 15
#
# ============================================================
#  Task: Calculate (8 + 2) * 5, then subtract 15
#
# ============================================================
#  Thought: First I need to add 8 and 2 to get the initial value.
#  Action: Use add tool → add(8, 2)
#  Observation: The add tool returned 10
#  Memory updated: {'step1': 10}
#
#  Thought: Now I should multiply the previous result by 5.
#  Action: Use multiply tool → multiply(10, 5)
#  Observation: The multiply tool returned 50
#  Memory updated: {'step1': 10, 'step2': 50}
#
#  Thought: Finally, I subtract 15 from the last result.
#  Action: Use subtract tool → subtract(50, 15)
#  Observation: The subtract tool returned 35
#  Memory updated: {'step1': 10, 'step2': 50, 'final': 35}
#
#  Final Answer: 35

# %% [markdown]
# ---
#
# ## PART 4: 🧠 From Manual to AI Brain - Using Real LLMs with OpenAI API
#
# So far, we've **manually** written what the agent thinks. But real agents have an **AI brain** that reasons automatically!
#
# Instead of us writing the reasoning, we use **OpenAI's GPT-4 model** via the **OpenAI API** to generate thoughts.
#
# ### The Complete Loop:
#
# **Task → [ Reason → Act → Observe → Remember ]* → Answer**
#
# At each iteration:
# 1. **🧠 Reason**: GPT-4 thinks about the task and what to do next
# 2. **🙌 Act**: Execute the tools GPT-4 requests
# 3. **👀 Observe**: Get the results back
# 4. **📝 Remember**: Add results to memory (conversation)
# 5. **🧠 Reason (again)**: Decide: Continue loop? Or give final answer?
#
# The loop **automatically stops** when:
# - ✅ GPT-4 returns a final answer (not a tool call)
# - ⚠️ Max iterations reached (safety limit)
#
# Let's build it!

# %% [markdown]
# # Step 1: Setup OpenAI Client

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv
import json

# Load environment variables from .env file
load_dotenv()

openai_endpoint = os.getenv("OPENAI_ENDPOINT")
openai_api_key = os.getenv("OPENAI_API_KEY")

MODEL = "gpt-4.1-mini"

if not openai_endpoint or not openai_api_key:
    raise ValueError("❌ OpenAI credentials not found!\n")

client = OpenAI(
    base_url=openai_endpoint,
    api_key=openai_api_key,
)

print(f"✅ OpenAI configured (model: {MODEL}")
#print(f"✅ OpenAI configured (openai_endpoint: {openai_endpoint}")
#print(f"✅ OpenAI configured (openai_api_key: {openai_api_key}")
# Out:
# ✅ OpenAI configured (model: gpt-4.1-mini

# %% [markdown]
# # Step 2: Define the Agent's Tools

# %% [markdown]
# ### Define tool functions

# %%
def add_numbers(a: float, b: float) -> dict:
    """Add two numbers."""
    return {"result": a + b}


def multiply_numbers(a: float, b: float) -> dict:
    """Multiply two numbers."""
    return {"result": a * b}


def divide_numbers(a: float, b: float) -> dict:
    """Divide two numbers (handles division by zero)."""
    if b == 0:
        return {"error": "Cannot divide by zero"}
    return {"result": a / b}


def final_answer(answer: str, explanation: str = ""):
    """Returns the final answer to the user."""
    return answer


# Tools the agent is allowed to call
tools = [add_numbers, multiply_numbers, divide_numbers, final_answer]

# %% [markdown]
# #### Create function declarations that will let the agent know what tools it can use.

# %%
# Tool name -> Python function mapping
TOOLS_MAP = {
    "add_numbers": add_numbers,
    "multiply_numbers": multiply_numbers,
    "divide_numbers": divide_numbers,
    # "final_answer" is handled specially inside react_cycle()
}

print("✅ Agent Tools Defined:")
for name in TOOLS_MAP.keys():
    print(f"   🙌 {name}")
# Out:
# ✅ Agent Tools Defined:
#    🙌 add_numbers
#    🙌 multiply_numbers
#    🙌 divide_numbers

# %% [markdown]
# # Step 3: The ReAct Cycle
#
# ## How It Works:
#
# 1. **Send user prompt + tools to GPT-4.1**: "Here's a task and here are the tools you can use"
# 2. **Loop**  until final answer is provided or max_iterations is reached:
#    - 🧠 GPT-4.1 thinks and decides: "Do I need a tool, or can I answer?"
#    - If tool needed:
#      - 🙌 GPT-4.1 tells us which tool and what arguments
#      - 👀 We call the tool and get result
#      - 📝 We add result to memory and send back to GPT-4.1
#    - If answer ready:
#      - ✅ Return the final answer and stop loop
#
# ## The Code:

# %% [markdown]
# #### Helper functions for tidy code.

# %%
import inspect
from typing import Callable, get_type_hints


def function_to_openai_tool(func: Callable) -> dict:
    """Convert a Python function to Responses API tool format."""

    sig = inspect.signature(func)
    hints = get_type_hints(func) if hasattr(func, "__annotations__") else {}

    properties = {}
    required = []

    for param_name, param in sig.parameters.items():
        param_type = hints.get(param_name, str)

        json_type = "string"
        if param_type in (int, float):
            json_type = "number"
        elif param_type is bool:
            json_type = "boolean"

        properties[param_name] = {"type": json_type}
        if param.default == inspect.Parameter.empty:
            required.append(param_name)

    return {
        "type": "function",
        "name": func.__name__,
        "description": func.__doc__ or "",
        "parameters": {
            "type": "object",
            "properties": properties,
            "required": required,
        },
    }

# %%
def get_response(
    input_items: list,
    tools: list,
    previous_response_id: str | None = None,
    instructions: str | None = None,
):
    """Call the OpenAI Responses API with tool support."""

    openai_tools = [function_to_openai_tool(t) for t in tools]
    return client.responses.create(
        model=MODEL,
        input=input_items,
        tools=openai_tools,
        tool_choice="auto",
        previous_response_id=previous_response_id,
        instructions=instructions,
    )

# %%
def execute_tool(tool_name: str, tool_args: dict, tool_map: dict):
    """Run a tool and return its result (or an error dict)."""

    if tool_name not in tool_map:
        return {"error": f"Tool '{tool_name}' not found"}

    try:
        return tool_map[tool_name](**(tool_args or {}))
    except Exception as exc:
        return {"error": str(exc)}

# %%
def extract_function_calls(response) -> list:
    """Return function_call items from a Responses API response."""

    return [
        item
        for item in (response.output or [])
        if getattr(item, "type", None) == "function_call"
    ]

# %% [markdown]
# #### ReAct Cycle function

# %%
DEFAULT_SYSTEM_INSTRUCTION = "Solve this task. You must use tools to help you."


def format_final_answer(tool_args: dict) -> str:
    """Format the final answer payload the model returns via the final_answer tool."""
    answer = tool_args.get("answer")
    explanation = tool_args.get("explanation")

    if explanation:
        # Make explanations easier to read by adding line breaks after sentences.
        explanation = explanation.replace(". ", ".\n")
        return f"{answer}\n\n📝 Explanation:\n{explanation}"

    return answer


def react_cycle(
    task: str,
    tools: list,
    tool_map: dict,
    system_instruction: str = DEFAULT_SYSTEM_INSTRUCTION,
    max_iterations: int = 10,
) -> str | None:
    """Run a simple ReAct loop: reason -> act -> observe -> repeat."""

    # We explicitly tell the model how to stop:
    # when it's done, it should call the `final_answer` tool.
    instructions = (
        f"{system_instruction} When you have the answer, use the final_answer tool."
    )

    # The Responses API can keep a server-side conversation thread.
    # We pass `previous_response_id` so each iteration continues the same conversation.
    previous_response_id = None

    # `messages` is what we send to the model each iteration.
    # First time: we send the user task.
    messages = [{"role": "user", "content": f"Task: {task}"}]

    for iteration in range(max_iterations):
        print(f"\n--- ITERATION {iteration + 1} ---")

        # 1) REASON: ask the model what to do next (and allow tool calling)
        try:
            response = get_response(
                messages,
                tools,
                previous_response_id=previous_response_id,
                instructions=instructions,
            )
            print("🧠 REASON")
        except Exception as exc:
            print(f"⚠️ Error during generation: {exc}")
            return None

        # Save response id so the next call continues the same thread.
        previous_response_id = response.id

        # 2) Check whether the model asked to call any tools.
        tool_calls = extract_function_calls(response)

        # If there are no tool calls, we expect the model to just answer normally.
        if not tool_calls:
            text = getattr(response, "output_text", None)
            if text:
                print(f"✅ FINAL ANSWER: {text}")
                return text

            print("⚠️ Model returned empty response (no text, no tools).")
            return None

        # 3) ACT + OBSERVE: run each requested tool and capture its output.
        tool_outputs = []
        for call in tool_calls:
            tool_name = call.name

            # Tool arguments arrive as JSON; parse them into a Python dict.
            tool_args = (
                json.loads(call.arguments) if getattr(call, "arguments", None) else {}
            )

            print(f"🙌 ACT: Calling '{tool_name}' with {tool_args}")

            # Special case: the model is done and wants to return a final answer.
            if tool_name == "final_answer":
                final_text = format_final_answer(tool_args)
                print(f"✅ FINAL ANSWER: {final_text}")
                return final_text

            # Normal tools (like add_numbers/multiply_numbers/divide_numbers)
            result = execute_tool(tool_name, tool_args, tool_map)
            print(f"👀 OBSERVE: Result = {result}")

            # 4) REMEMBER: store tool result in the exact format the Responses API expects,
            # so we can send it back to the model on the next iteration.
            tool_outputs.append(
                {
                    "type": "function_call_output",
                    "call_id": call.call_id,
                    "output": json.dumps(result),
                }
            )
            print(f"📝 REMEMBER: Stored result for '{tool_name}'")

        # Next iteration: we send ONLY the tool outputs.
        # The model will still know the task because we continue the same thread
        # using `previous_response_id`.
        messages = tool_outputs

    print(f"⚠️ Max iterations ({max_iterations}) reached")
    return None


# Test the ReAct cycle with a sample task
result = react_cycle(
    "Multiply 12 by 8, then divide by 4",
    tools,
    TOOLS_MAP,
)
# Out:
# --- ITERATION 1 ---
# 🧠 REASON
# 🙌 ACT: Calling 'multiply_numbers' with {'a': 12, 'b': 8}
# 👀 OBSERVE: Result = {'result': 96}
# 📝 REMEMBER: Stored result for 'multiply_numbers'
# 🙌 ACT: Calling 'divide_numbers' with {'a': 96, 'b': 4}
# 👀 OBSERVE: Result = {'result': 24.0}
# 📝 REMEMBER: Stored result for 'divide_numbers'
#
# --- ITERATION 2 ---
# 🧠 REASON
# 🙌 ACT: Calling 'final_answer' with {'answer': '24', 'explanation': 'First, I multiplied 12 by 8 to get 96. Then, I divided 96 by 4 to get 24.'}
# ✅ FINAL ANSWER: 24
#
# 📝 Explanation:
# First, I multiplied 12 by 8 to get 96.
# Then, I divided 96 by 4 to get 24.

# %% [markdown]
# ### Exercise 4: Test the Agent with Your Own Task 🤖
#
# The `react_cycle` function is your AI agent! Try giving it a **different math problem** and watch the ReAct loop in action.
#
# Ideas to try:
# - `"What is 999 divided by 3, then add 7?"`
# - `"Multiply 12 by 8, then divide by 4"`
# - `"Add 100 and 250, then multiply by 0"`

# %%
result = react_cycle(
    "Add 100 and 250, then multiply by 0",
    tools,
    TOOLS_MAP)
# Out:
# --- ITERATION 1 ---
# 🧠 REASON
# 🙌 ACT: Calling 'add_numbers' with {'a': 100, 'b': 250}
# 👀 OBSERVE: Result = {'result': 350}
# 📝 REMEMBER: Stored result for 'add_numbers'
# 🙌 ACT: Calling 'multiply_numbers' with {'a': 350, 'b': 0}
# 👀 OBSERVE: Result = {'result': 0}
# 📝 REMEMBER: Stored result for 'multiply_numbers'
#
# --- ITERATION 2 ---
# 🧠 REASON
# 🙌 ACT: Calling 'final_answer' with {'answer': '0', 'explanation': 'First, 100 and 250 were added to get 350. Then, 350 was multiplied by 0, resulting in 0.'}
# ✅ FINAL ANSWER: 0
#
# 📝 Explanation:
# First, 100 and 250 were added to get 350.
# Then, 350 was multiplied by 0, resulting in 0.

# %%
# TODO: Write your own task and run the react_cycle!
# my_task = "Your math question here"
# my_result = react_cycle(my_task, tools, TOOLS_MAP)
# print(f"\n🎯 Agent's answer: {my_result}")

# %% [markdown]
# ### Exercise 4b: Expand the Agent's Toolbox 🧰
#
# The LLM-powered agent currently only has `add_numbers`, `multiply_numbers`, and `divide_numbers`. But it can't subtract!
#
# **Task:**
# 1. Create a new `subtract_numbers(a, b)` function (same style as the others — typed parameters, returns a dict)
# 2. Add it to the `tools` list AND the `TOOLS_MAP`
# 3. Test the agent with a task that **requires subtraction**, like: `"What is 500 minus 137, then multiply by 2?"`

# %%
# TODO: Create a subtract_numbers tool (same style as add_numbers)
def subtract_numbers(a: float, b: float) -> dict:
    """subtract two numbers."""
    return {"result": a - b}


# TODO: Add it to the tools list and TOOLS_MAP
tools = [add_numbers, multiply_numbers, divide_numbers, final_answer, subtract_numbers]
TOOLS_MAP = {
    "add_numbers": add_numbers,
    "multiply_numbers": multiply_numbers,
    "divide_numbers": divide_numbers,
    "subtract_numbers": subtract_numbers,
    # "final_answer" is handled specially inside react_cycle()
}


# TODO: Test the agent with a subtraction task
result = react_cycle(
    "What is 500 minus 137, then multiply by 2?",
    tools,
    TOOLS_MAP)
# Out:
# --- ITERATION 1 ---
# 🧠 REASON
# 🙌 ACT: Calling 'subtract_numbers' with {'a': 500, 'b': 137}
# 👀 OBSERVE: Result = {'result': 363}
# 📝 REMEMBER: Stored result for 'subtract_numbers'
#
# --- ITERATION 2 ---
# 🧠 REASON
# 🙌 ACT: Calling 'multiply_numbers' with {'a': 363, 'b': 2}
# 👀 OBSERVE: Result = {'result': 726}
# 📝 REMEMBER: Stored result for 'multiply_numbers'
#
# --- ITERATION 3 ---
# 🧠 REASON
# 🙌 ACT: Calling 'final_answer' with {'answer': '726', 'explanation': 'First, subtract 137 from 500 to get 363. Then multiply 363 by 2 to get 726.'}
# ✅ FINAL ANSWER: 726
#
# 📝 Explanation:
# First, subtract 137 from 500 to get 363.
# Then multiply 363 by 2 to get 726.

# %% [markdown]
# ### Exercise 4c: Change the Agent's Personality 🎭
#
# The `system_instruction` parameter controls **how** the agent behaves — its personality, style, and rules.
#
# **Task:** Run the **same math task** with two different system instructions and compare the results:
# 1. `"You are a precise math teacher. Show your work step by step."`
# 2. `"You are a pirate. Answer like a pirate but still use tools for calculations."`
#
# **What to observe:** How does the system instruction change the agent's behavior? Does it affect tool usage or just the final answer text?

# %%
# TODO: Try the same task with two different system instructions (see descriptions above)
task = "Calculate 15 + 27, then multiply by 3"

# TODO: Instruction 1
result = react_cycle(
    task = "Calculate 15 + 27, then multiply by 3",
    tools=tools,
    tool_map=TOOLS_MAP,
    system_instruction = "You are a precise math teacher. Show your work step by step.")

# TODO: Instruction 2
result = react_cycle(
    task = "Calculate 15 + 27, then multiply by 3",
    tools=tools,
    tool_map=TOOLS_MAP,
    system_instruction = "You are a pirate. Answer like a pirate but still use tools for calculations.")
# Out:
# --- ITERATION 1 ---
# 🧠 REASON
# 🙌 ACT: Calling 'add_numbers' with {'a': 15, 'b': 27}
# 👀 OBSERVE: Result = {'result': 42}
# 📝 REMEMBER: Stored result for 'add_numbers'
#
# --- ITERATION 2 ---
# 🧠 REASON
# 🙌 ACT: Calling 'multiply_numbers' with {'a': 42, 'b': 3}
# 👀 OBSERVE: Result = {'result': 126}
# 📝 REMEMBER: Stored result for 'multiply_numbers'
#
# --- ITERATION 3 ---
# 🧠 REASON
# 🙌 ACT: Calling 'final_answer' with {'answer': '126', 'explanation': 'First, we add 15 and 27 to get 42. Then, we multiply 42 by 3 to get 126.'}
# ✅ FINAL ANSWER: 126
#
# 📝 Explanation:
# First, we add 15 and 27 to get 42.
# Then, we multiply 42 by 3 to get 126.
#
# --- ITERATION 1 ---
# 🧠 REASON
# 🙌 ACT: Calling 'add_numbers' with {'a': 15, 'b': 27}
# 👀 OBSERVE: Result = {'result': 42}
# 📝 REMEMBER: Stored result for 'add_numbers'
#
# --- ITERATION 2 ---
# 🧠 REASON
# 🙌 ACT: Calling 'multiply_numbers' with {'a': 42, 'b': 3}
# 👀 OBSERVE: Result = {'result': 126}
# 📝 REMEMBER: Stored result for 'multiply_numbers'
#
# --- ITERATION 3 ---
# 🧠 REASON
# 🙌 ACT: Calling 'final_answer' with {'answer': '126', 'explanation': "Arrr, when ye add 15 and 27, ye get 42, and then when ye multiply that by 3, ye get 126. That's the treasure ye seek!"}
# ✅ FINAL ANSWER: 126
#
# 📝 Explanation:
# Arrr, when ye add 15 and 27, ye get 42, and then when ye multiply that by 3, ye get 126.
# That's the treasure ye seek!

# %% [markdown]
# ### Exercise 4d: Test Edge Cases & Safety Limits ⚠️
#
# Agents can get **stuck in loops** or take too many steps. The `max_iterations` parameter is a safety net.
#
# **Task 1:** Run a complex multi-step task with `max_iterations=1`. What happens?
#
# **Task 2:** Ask the agent to divide by zero: `"What is 10 divided by 0?"`. How does the agent handle the error from the tool?
#
# **Key Insight:** These edge cases show why agents need good error handling, iteration limits, and clear tool descriptions!

# %%
# TODO Task 1: Test with max_iterations=1 on a multi-step problem
# What happens when the agent doesn't have enough iterations?
result = react_cycle(
    task = "Calculate 15 + 27, then multiply by 3",
    tools=tools,
    tool_map=TOOLS_MAP,
    system_instruction = "You are a pirate. Answer like a pirate but still use tools for calculations.",
    max_iterations = 1)
# Out:
# --- ITERATION 1 ---
# 🧠 REASON
# 🙌 ACT: Calling 'add_numbers' with {'a': 15, 'b': 27}
# 👀 OBSERVE: Result = {'result': 42}
# 📝 REMEMBER: Stored result for 'add_numbers'
# ⚠️ Max iterations (1) reached

# %%
# TODO Task 2: Test division by zero — how does the agent handle tool errors?
result = react_cycle(
    task = "What is 10 divided by 0?",
    tools=tools,
    tool_map=TOOLS_MAP,
    system_instruction = "You are a pirate. Answer like a pirate but still use tools for calculations."
    )
# Out:
# --- ITERATION 1 ---
# 🧠 REASON
# 🙌 ACT: Calling 'divide_numbers' with {'a': 10, 'b': 0}
# 👀 OBSERVE: Result = {'error': 'Cannot divide by zero'}
# 📝 REMEMBER: Stored result for 'divide_numbers'
#
# --- ITERATION 2 ---
# 🧠 REASON
# 🙌 ACT: Calling 'final_answer' with {'answer': 'Division by zero is impossible, matey! Ye cannot divide a number by zero on these seas.', 'explanation': "Dividing any number by zero is undefined in mathematics, so it can't be done."}
# ✅ FINAL ANSWER: Division by zero is impossible, matey! Ye cannot divide a number by zero on these seas.
#
# 📝 Explanation:
# Dividing any number by zero is undefined in mathematics, so it can't be done.

# %% [markdown]
# ## PART 5: 🚀 Challenge: Build a Web Search Agent!
#
# Now it's time to give your agent **super-vision**!
#
# Your agent is smart, but it doesn't know about current events (like today's news). We'll fix that by giving it a "Web Search" hand using **Tavily**, a search engine built specifically for AI agents.
#
# ### 1. Get your Tavily API key 🔑 (5 minutes)
# 1. Create a free account at [tavily.com](https://tavily.com).
#
#
#
# 2. Copy the default API key.
# 3. Add it to your `.env` file: `TAVILY_API_KEY=tvly-...`
#
#
# ### 2. The Mission 🕵️‍♂️
# Build an agent that can answer:
# > **"What is the weather today in Latvia and Lithuania?"**
#
# ### 3. Your Toolkit 🧰
# You'll need to:
# 1.  Create a `search_web(query)` function using Tavily.
# 2.  Add it to your `tools` list.
# 3.  Update the `TOOLS_MAP`.
# 4.  Run the `react_cycle` with a question that needs searching!

# %%
# !pip install tavily-python
# Out:
# Requirement already satisfied: tavily-python in /usr/local/lib/python3.12/dist-packages (0.7.21)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from tavily-python) (2.32.4)
# Requirement already satisfied: tiktoken>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tavily-python) (0.12.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from tavily-python) (0.28.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.5.1->tavily-python) (2025.11.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->tavily-python) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->tavily-python) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->tavily-python) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->tavily-python) (2026.1.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->tavily-python) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->tavily-python) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->tavily-python) (0.16.0)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx->tavily-python) (4.15.0)

# %%
from tavily import TavilyClient

# 1. Setup Tavily
tavily_api_key = os.getenv("TAVILY_API_KEY")
if not tavily_api_key:
    raise ValueError(
        "❌ TAVILY_API_KEY not found!\n"
        "   Make sure your .env file contains: TAVILY_API_KEY=your-api-key\n"
    )

tavily_client = TavilyClient(api_key=tavily_api_key)


# 2. CREATE YOUR SEARCH TOOL
def search_web(query: str) -> dict:
    """
    Searches the web for the given query.
    Useful for getting up-to-date information, news, or facts.
    """
    # TODO: Use tavily_client.search() to get results and return them as a dict
    # Hint: Look at the tavily_client.search() method and its max_results parameter
    response = tavily_client.search(
        query=query,
        max_results=5)
    return response


# 3. UPDATE YOUR TOOL LISTS
# TODO: Add your new search_web tool and final_answer to the tools list for OpenAI
my_new_tools = [search_web, final_answer]

# TODO: Add the tool mapping (string name to function)
# Note: "final_answer" is handled specially inside react_cycle(), so don't add it here!
MY_TOOLS_MAP = {"search_web": search_web}

# %%
result = react_cycle(
    task = "What is the weather today in Latvia and Lithuania?",
    tools=my_new_tools,
    tool_map=MY_TOOLS_MAP
    )
# Out:
# --- ITERATION 1 ---
# 🧠 REASON
# 🙌 ACT: Calling 'search_web' with {'query': 'weather today in Latvia'}
# 👀 OBSERVE: Result = {'query': 'weather today in Latvia', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'title': 'Weather in Latvia', 'url': 'https://www.weatherapi.com/', 'content': "{'location': {'name': 'Riga', 'region': 'Riga', 'country': 'Latvia', 'lat': 56.95, 'lon': 24.1, 'tz_id': 'Europe/Riga', 'localtime_epoch': 1772026027, 'localtime': '2026-02-25 15:27'}, 'current': {'last_updated_epoch': 1772025300, 'last_updated': '2026-02-25 15:15', 'temp_c': -1.9, 'temp_f': 28.6, 'is_day': 1, 'condition': {'text': 'Overcast', 'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png', 'code': 1009}, 'wind_mph': 2.5, 'wind_kph': 4.0, 'wind_degree': 50, 'wind_dir': 'NE', 'pressure_mb': 1025.0, 'pressure_in': 30.27, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 74, 'cloud': 0, 'feelslike_c': -3.2, 'feelslike_f': 26.3, 'windchill_c': -1.6, 'windchill_f': 29.1, 'heatindex_c': -0.5, 'heatindex_f': 31.1, 'dewpoint_c': -2.6, 'dewpoint_f': 27.3, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 0.6, 'gust_mph': 3.4, 'gust_kph': 5.5}}", 'score': 0.9999731, 'raw_content': None}, {'url': 'https://forecast.lv/en/w/vies%C3%A4,latvija/2day', 'title': 'Forecast Latvia 5 days', 'content': 'Weather forecast Latvia 25-02-2026 ; Forecast from -13 °C to -3 °C and precipitation · Temperature · -15 °C ; Cloud cover · Cloud cover · 0% ; Wind speed and direction.', 'score': 0.9999646, 'raw_content': None}, {'url': 'https://www.weatherbug.com/weather-forecast/now/riga-latvia-lg', 'title': 'Riga, Latvia, LV Weather Today & Tomorrow - Local Forecast & Live ...', 'content': 'Riga, Latvia, LV Weather. As of Feb 25, 2026 12:50 PM. Weather Station:RIGA AIRPORT. 28°degrees Fahrenheit. Feels like:23°F. Hi: 30°FLo: 19°F. Mostly Sunny', 'score': 0.9999292, 'raw_content': None}, {'url': 'https://eng.lsm.lv/article/weather/weather/25.02.2026-wednesday-will-be-pleasantly-sunny-and-dry-in-latvia.a636256/', 'title': 'Wednesday will be pleasantly sunny and dry in Latvia - LSM', 'content': 'Wednesday in Latvia will be mostly sunny and dry, with light snow expected in the southeast in the morning, according to the Latvian', 'score': 0.9998233, 'raw_content': None}, {'url': 'https://en.ilmatieteenlaitos.fi/weather/latvia/riga', 'title': 'Weather in Riga, Latvia - Finnish Meteorological Institute', 'content': 'Forecast updated 25.2.2026 2:27. Riga, Latvia. Daily hourly forecast tables as a list, the tables are shown and hidden from a button. Wed 25.2.15:00 1°. Time', 'score': 0.99945146, 'raw_content': None}], 'response_time': 1.7, 'request_id': 'f67ea7da-59e3-4015-9bac-1fdaefb74eb9'}
# 📝 REMEMBER: Stored result for 'search_web'
# 🙌 ACT: Calling 'search_web' with {'query': 'weather today in Lithuania'}
# 👀 OBSERVE: Result = {'query': 'weather today in Lithuania', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'title': 'Weather in Lithuania', 'url': 'https://www.weatherapi.com/', 'content': "{'location': {'name': 'Vilnius', 'region': 'Vilniaus Apskritis', 'country': 'Lithuania', 'lat': 54.683, 'lon': 25.317, 'tz_id': 'Europe/Vilnius', 'localtime_epoch': 1772026074, 'localtime': '2026-02-25 15:27'}, 'current': {'last_updated_epoch': 1772025300, 'last_updated': '2026-02-25 15:15', 'temp_c': -2.0, 'temp_f': 28.4, 'is_day': 1, 'condition': {'text': 'Overcast', 'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png', 'code': 1009}, 'wind_mph': 6.3, 'wind_kph': 10.1, 'wind_degree': 23, 'wind_dir': 'NNE', 'pressure_mb': 1022.0, 'pressure_in': 30.18, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 93, 'cloud': 100, 'feelslike_c': -5.7, 'feelslike_f': 21.7, 'windchill_c': -4.6, 'windchill_f': 23.8, 'heatindex_c': -1.0, 'heatindex_f': 30.1, 'dewpoint_c': -3.0, 'dewpoint_f': 26.6, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 0.3, 'gust_mph': 8.5, 'gust_kph': 13.7}}", 'score': 0.980287, 'raw_content': None}, {'url': 'https://world-weather.info/forecast/lithuania/silale/february-2026/', 'title': 'Weather in Šilalė in February 2026 (Tauragė County)', 'content': "Šilalė Weather Forecast for February 2026, is based on previous years' statistical data. ... Wednesday, 25 February. Day. +36°. 10.5. 29.5. 76%. +27°. 07:31 AM.", 'score': 0.92491204, 'raw_content': None}, {'url': 'https://weather.knopka.ca/f/countries/europe/Lithuania/Vilnius/?view=3hour&date=2026-02-25', 'title': 'Vilnius, Lithuania: 3 hour detailed weather forecast for 2026-02-25', 'content': '05:00 · 0° feels like: -5° · Relative humidity: 93% Pressure 745 mm. Precipitations: 0.3 mm. Wind: 18 km/h, SW ; 08:00 · +1° feels like: +-5°.', 'score': 0.90985113, 'raw_content': None}, {'url': 'https://www.weather25.com/europe/lithuania?page=month&month=February', 'title': 'Lithuania weather in February 2026', 'content': 'The weather in Lithuania in February is very cold with temperatures between 21°F and 30°F, warm clothes are a must. You can expect about 3 to 8 days of rain in', 'score': 0.8987045, 'raw_content': None}, {'url': 'https://www.sunheron.com/europe/lithuania-weather-february/', 'title': 'Lithuania weather in February 2026', 'content': 'In February in Lithuania, the average air temperature ranges from 0 °C (32 °F) during the day to -5 °C (23 °F) at night. There are 11 days of rain on average.', 'score': 0.8488849, 'raw_content': None}], 'response_time': 1.53, 'request_id': '330acd3e-80a0-4e2e-8c1d-610ceece64a3'}
# 📝 REMEMBER: Stored result for 'search_web'
#
# --- ITERATION 2 ---
# 🧠 REASON
# 🙌 ACT: Calling 'final_answer' with {'answer': "Today's weather in Latvia (Riga) is overcast with a temperature of about -1.9°C (28.6°F). The wind is from the northeast at 4 kph, and humidity is around 74%. In Lithuania (Vilnius), the weather is also overcast with a temperature of about -2.0°C (28.4°F). The wind is from the north-northeast at 10.1 kph, and humidity is around 93%. Both countries are experiencing cold and overcast conditions today.", 'explanation': 'I searched for the current weather in Latvia and Lithuania. In Latvia, specifically Riga, the temperature is about -1.9°C with overcast skies. In Lithuania, specifically Vilnius, the temperature is about -2.0°C with overcast skies as well. Wind speeds and humidity levels were also noted for both locations to provide a full picture of the current weather conditions.'}
# ✅ FINAL ANSWER: Today's weather in Latvia (Riga) is overcast with a temperature of about -1.9°C (28.6°F). The wind is from the northeast at 4 kph, and humidity is around 74%. In Lithuania (Vilnius), the weather is also overcast with a temperature of about -2.0°C (28.4°F). The wind is from the north-northeast at 10.1 kph, and humidity is around 93%. Both countries are experiencing cold and overcast conditions today.
#
# 📝 Explanation:
# I searched for the current weather in Latvia and Lithuania.
# In Latvia, specifically Riga, the temperature is about -1.9°C with overcast skies.
# In Lithuania, specifically Vilnius, the temperature is about -2.0°C with overcast skies as well.
# Wind speeds and humidity levels were also noted for both locations to provide a full picture of the current weather conditions.

# %%
# 4. USE IT
# Ask a question that requires searching the web
question = (
    "What is the current stock price of Tesla? And what is 10 shares of it worth?"
)

# Run the cycle!
# Now we explicitely pass our tools and a custom system prompt
system_prompt = (
    "You are a helpful assistant with access to the web. "
    "Use the search_web tool to find real-time information."
)

answer = react_cycle(
    question,
    tools=my_new_tools,
    tool_map=MY_TOOLS_MAP,
    system_instruction=system_prompt,
)
# Out:
# --- ITERATION 1 ---
# 🧠 REASON
# 🙌 ACT: Calling 'search_web' with {'query': 'Tesla current stock price'}
# 👀 OBSERVE: Result = {'query': 'Tesla current stock price', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.macrotrends.net/stocks/charts/TSLA/tesla/stock-price-history', 'title': 'Tesla - 15 Year Stock Price History | TSLA', 'content': 'The latest closing stock price for Tesla as of February 24, 2026 is 409.40. An investor who bought $1,000 worth of Tesla stock at the IPO in 2010 would have', 'score': 0.99980897, 'raw_content': None}, {'url': 'https://www.investing.com/equities/tesla-motors-chart', 'title': 'Tesla (TSLA) Stock Chart', 'content': 'The Tesla stock price today is 409.38. What is the 52-Week Range for Tesla ... The Tesla stock price has ranged from 397.64 to 410.82 today. Find a', 'score': 0.9998029, 'raw_content': None}, {'url': 'https://robinhood.com/us/en/stocks/TSLA/', 'title': 'Tesla: TSLA Stock Price Quote & News', 'content': 'At a current price of $408.88, the stock is -0.1% higher than the low and still -0.6% under the high. Trading volume for Tesla(TSLA) stock has reached 203.14K,', 'score': 0.9997428, 'raw_content': None}, {'url': 'https://www.tradingview.com/symbols/NASDAQ-TSLA/', 'title': 'TSLA Stock Price — Tesla Chart - TradingView', 'content': 'The current price of TSLA is 409.38 USD — it has increased by 2.45% in the past 24 hours. Watch Tesla, Inc. stock price performance more closely on the chart.', 'score': 0.9997086, 'raw_content': None}, {'url': 'https://www.google.com/finance/quote/TSLA:NASDAQ?hl=en', 'title': 'Tesla Inc (TSLA) Stock Price & News - Finance', 'content': 'Previous close. The last closing price. $399.83 ; Day range. The range between the high and low prices over the past day. $397.64 - $410.82 ; Year range. The', 'score': 0.99879336, 'raw_content': None}], 'response_time': 0.56, 'request_id': 'c9018a2f-d857-4a84-9af1-ee346e080cab'}
# 📝 REMEMBER: Stored result for 'search_web'
#
# --- ITERATION 2 ---
# 🧠 REASON
# 🙌 ACT: Calling 'final_answer' with {'answer': 'The current stock price of Tesla is approximately $409.38. Therefore, 10 shares of Tesla would be worth approximately $4093.80.', 'explanation': "Based on the latest data from multiple sources, Tesla's stock price is around $409.38. Multiplying this by 10 shares gives $4093.80 as the total value of 10 shares."}
# ✅ FINAL ANSWER: The current stock price of Tesla is approximately $409.38. Therefore, 10 shares of Tesla would be worth approximately $4093.80.
#
# 📝 Explanation:
# Based on the latest data from multiple sources, Tesla's stock price is around $409.38.
# Multiplying this by 10 shares gives $4093.80 as the total value of 10 shares.

# %% [markdown]
# ### Exercise 5: Ask a Multi-Step Web + Math Question 🌐🧮
#
# Now ask your agent a question that requires **both** web search **and** math!
#
# The agent should:
# 1. Search the web for some information
# 2. Use that information in a calculation
#
# Example questions:
# - `"What is the population of Lithuania? Divide it by 1000."`
# - `"Search for the height of the Eiffel Tower in meters, then multiply it by 3."`
# - `"What is the weather in Latvia? If the temperature is above 20, add 5, otherwise subtract 5."`

# %%
# TODO: Ask a question that needs BOTH web search and math
# Use react_cycle with your tools and an appropriate system instruction

result = react_cycle(
    task = "What is the population of Lithuania? Divide it by 1000.",
    tools=my_new_tools,
    tool_map=MY_TOOLS_MAP
    )
# Out:
# --- ITERATION 1 ---
# 🧠 REASON
# 🙌 ACT: Calling 'search_web' with {'query': 'population of Lithuania'}
# 👀 OBSERVE: Result = {'query': 'population of Lithuania', 'response_time': 1.18, 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://osp.stat.gov.lt/en/lietuvos-gyventojai-2023/salies-gyventojai/gyventoju-skaicius-ir-sudetis', 'title': 'The population of Lithuania (edition 2023)', 'content': 'The estimated resident population of Lithuania amounted to 2 million 857 thousand, ie by 51.3 thousand persons more than at the beginning of 2022.', 'score': 0.9277898, 'raw_content': None}, {'url': 'https://worldpopulationreview.com/countries/lithuania', 'title': 'Lithuania Population 2026 - World Population Review', 'content': "### Lithuania Population. ## Population of Lithuania. Lithuania's population structure shows a notably lower male to female ratio of 0.90 to 1, with a median male age of 40.47 years old and a median female age of 47.50 years old. #### Lithuania Adults. # Lithuania. ## Lithuania Population Clock. ## Lithuania Overview. ## Lithuania Demographics. Lithuania has a fairly homogeneous population with no apparent genetic differences between subgroups of ethnicities. Ethnic Lithuanians account for 5/6 of the population, which makes the country one of the most homogeneous in the Baltic States. There are 2,310,286 adults, (596,458 of whom are seniors) in Lithuania. ## Lithuania Religion, Economy and Politics. The age structure in Lithuania is around 26% under the age of 25, 54% between the ages of 25 and 64, and nearly 20% are over the age of 65. ## Quality of Life in Lithuania. 2. World Population Prospects (2024 Revision)  - Lithuania United Nations Graphs/Profiles.", 'score': 0.89501935, 'raw_content': None}, {'url': 'https://www.worldometers.info/world-population/lithuania-population/', 'title': 'Lithuania Population (2026) - Worldometer', 'content': "| Year | Population | Yearly % Change | Yearly Change | Migrants (net) | Median Age | Fertility Rate | Density (P/Km²) | Urban Pop % | Urban Population | Country's Share of World Pop | World Population | Lithuania Global Rank |. | Year | Population | Yearly % Change | Yearly Change | Migrants (net) | Median Age | Fertility Rate | Density (P/Km²) | Urban Pop % | Urban Population | Country's Share of World Pop | World Population | Lithuania Global Rank |. The **Population of Lithuania (1950 - 2026)** chart plots the total population count as of July 1 of each year, from 1950 to 2026. **Population**: Overall total population (both sexes and all ages) in the country as of July 1 of the year indicated, as estimated by the United Nations, Department of Economic and Social Affairs, Population Division. **Country's Share of World Pop**: Total population in the country as a percentage of total World Population as of July 1 of the year indicated.", 'score': 0.85825616, 'raw_content': None}, {'url': 'https://www.osw.waw.pl/en/publikacje/osw-commentary/2024-12-03/lithuania-losing-people-without-a-fight', 'title': 'Lithuania is losing people without a fight - OSW', 'content': 'While Lithuanian data suggests that the country’s population has been reduced by approximately15% due to emigration since 1990, accounting for the descendants of emigrants not included in the statistics could increase this figure to 25%. Source: *The population of Lithuania (edition 2023)*, Official Statistics Portal, osp.stat.gov.lt. The most notable demographic shift reflecting the ageing of Lithuania’s population over the past decade has been a 27.9% decline in the number of individuals aged 15–29. The second most significant factor negatively affecting Lithuania’s population, after emigration, is the persistently low birth rate. Currently, 221,000 foreigners reside in Lithuania, including 116,000 on temporary residence permits for employment. Legal immigrants increasingly choose to stay longer in Lithuania, with proof of this being the growing number of temporary (including renewed) and permanent residence permits issued. Despite these trends, the total number of foreigners ...
# 📝 REMEMBER: Stored result for 'search_web'
#
# --- ITERATION 2 ---
# 🧠 REASON
# 🙌 ACT: Calling 'final_answer' with {'answer': 'The population of Lithuania is approximately 2,857,000. Dividing this by 1000 gives 2,857.', 'explanation': 'According to the latest statistics, the estimated resident population of Lithuania is about 2 million 857 thousand. When divided by 1000, the result is 2,857.'}
# ✅ FINAL ANSWER: The population of Lithuania is approximately 2,857,000. Dividing this by 1000 gives 2,857.
#
# 📝 Explanation:
# According to the latest statistics, the estimated resident population of Lithuania is about 2 million 857 thousand.
# When divided by 1000, the result is 2,857.

# %%
result = react_cycle(
    task = "Search for the height of the Eiffel Tower in meters, then multiply it by 3.",
    tools=my_new_tools,
    tool_map=MY_TOOLS_MAP
    )
# Out:
# --- ITERATION 1 ---
# 🧠 REASON
# 🙌 ACT: Calling 'search_web' with {'query': 'height of the Eiffel Tower in meters'}
# 👀 OBSERVE: Result = {'query': 'height of the Eiffel Tower in meters', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.toureiffel.paris/en/news/history-and-culture/300-330-meters-story-towers-height', 'title': "From 300 to 330 meters : the story of the Tower's height - La tour Eiffel", 'content': '1949: a new television antenna enabled a “high-definition” 819-line transmitter to be installed, adding ten feet to the height of the Tower and enabling two programs to be broadcast simultaneously! A new antenna added ten feet to the height of the Tower. In 2000, the arrival of digital terrestrial television saw a new UHF (Ultra High Frequency) antenna installed, taking the Tower to a height of 1,063 feet. All this new equipment took the Eiffel Tower to a height of 320,75 meters (1,050 feet)! The installation of a new UHF (Ultra High Frequency) antenna for Digital Terrestrial Television and its base which changed the height of the tower again, making it 324 meters tall (1,063 feet). The Eiffel Tower reached the height of **330 meters (1,083 feet) on March 15, 2022** thanks to this successful and dizzying operation carried out by helicopter. With the installation of a new digital terrestrial radio antenna by TDF, the Tower will grow by 6 meters (20 feet).', 'score': 0.9997981, 'raw_content': None}, {'url': 'https://www.toureiffel.paris/en/news/events/eiffel-tower-grows-330-meters-tall', 'title': 'The Eiffel Tower grows to 330 meters tall!', 'content': 'Open today 09:30 - 23:00. # The Eiffel Tower grows to 330 meters tall! March 15, 2022, marks a historic date for the Eiffel Tower, which has always played its part in major innovations in radio and television. The Eiffel Tower will grow to a height of 330 meters (1,083 feet) with the installation of a 6 meters radio antenna by **TDF** in preparation for DAB+ digital radio broadcasting. Watch the spectacular operation to install the device by helicopter, carried out at 11am on March 15, 2022. The device joins the dozens of other antennas that allow TDF to broadcast nearly 30 DTT channels and 32 radio stations to 12 million people in Île-de-France within a radius of nearly 50 miles from the Eiffel Tower. Today  09:30 - 23:00. From 300 to 330 meters: the story of the Tower’s height. Since it was built, the Eiffel Tower never stopped growing! The Eiffel Tower was supposed to be dismantled after 20 years. How the Eiffel Tower was a science lab?', 'score': 0.999089, 'raw_content': None}, {'url': 'https://www.britannica.com/topic/Eiffel-Tower-Paris-France', 'title': 'Eiffel Tower | History, Height, & Facts | Britannica', 'content': 'When the Eiffel Tower was completed, it stood at 300 meters (984 feet) high, making it the tallest structure in the world until the topping off', 'score': 0.9979493, 'raw_content': None}, {'url': 'https://en.wikipedia.org/wiki/Eiffel_Tower', 'title': 'Eiffel Tower - Wikipedia', 'content': '+ 5.2 Structures in France taller than the Eiffel Tower. # Eiffel Tower. The **Eiffel Tower** (/ˈaɪfəl/ ⓘ *EYE-fəl*; French: *Tour Eiffel*  ⓘ) is a lattice tower on the Champ de Mars in Paris, France. During its construction, the Eiffel Tower surpassed the Washington Monument to become by far the tallest human-made structure in the world, a title it held for 41 years until the Chrysler Building in New York City was finished in 1930. According to *The New York Times*, "[at] a time when the [CIC] was helping finance one of the world\'s best-known landmarks, the Eiffel Tower, as a monument to French liberty, it was choking Haiti\'s economy, taking much of the young nation\'s income back to Paris and impairing its ability to start schools, hospitals and the other building blocks of an independent country.". "Origins and construction of the Eiffel Tower". **^** "Construction of the Eiffel Tower". "The Eiffel Tower\'s lifts". **^** "Eiffel Tower (Paris ( 7 th ), 1889)".', 'score': 0.61138195, 'raw_content': None}, {'url': 'https://www.facebook ...
# 📝 REMEMBER: Stored result for 'search_web'
#
# --- ITERATION 2 ---
# 🧠 REASON
# 🙌 ACT: Calling 'final_answer' with {'answer': 'The current height of the Eiffel Tower is 330 meters. Multiplying this by 3 gives 990 meters.', 'explanation': 'The latest height of the Eiffel Tower is 330 meters as of March 15, 2022, after the installation of a new antenna. Multiplying 330 meters by 3 results in 990 meters.'}
# ✅ FINAL ANSWER: The current height of the Eiffel Tower is 330 meters. Multiplying this by 3 gives 990 meters.
#
# 📝 Explanation:
# The latest height of the Eiffel Tower is 330 meters as of March 15, 2022, after the installation of a new antenna.
# Multiplying 330 meters by 3 results in 990 meters.

# %%
result = react_cycle(
    task = "What is the weather in Latvia? If the temperature is above 20, add 5, otherwise subtract 5.",
    tools=my_new_tools,
    tool_map=MY_TOOLS_MAP
    )
# Out:
# --- ITERATION 1 ---
# 🧠 REASON
# 🙌 ACT: Calling 'search_web' with {'query': 'current weather in Latvia'}
# 👀 OBSERVE: Result = {'query': 'current weather in Latvia', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'title': 'Weather in Latvia', 'url': 'https://www.weatherapi.com/', 'content': "{'location': {'name': 'Riga', 'region': 'Riga', 'country': 'Latvia', 'lat': 56.95, 'lon': 24.1, 'tz_id': 'Europe/Riga', 'localtime_epoch': 1772026377, 'localtime': '2026-02-25 15:32'}, 'current': {'last_updated_epoch': 1772026200, 'last_updated': '2026-02-25 15:30', 'temp_c': -2.7, 'temp_f': 27.1, 'is_day': 1, 'condition': {'text': 'Overcast', 'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png', 'code': 1009}, 'wind_mph': 2.5, 'wind_kph': 4.0, 'wind_degree': 50, 'wind_dir': 'NE', 'pressure_mb': 1026.0, 'pressure_in': 30.3, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 80, 'cloud': 0, 'feelslike_c': -4.1, 'feelslike_f': 24.7, 'windchill_c': -1.6, 'windchill_f': 29.1, 'heatindex_c': -0.5, 'heatindex_f': 31.1, 'dewpoint_c': -2.6, 'dewpoint_f': 27.3, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 0.6, 'gust_mph': 3.4, 'gust_kph': 5.5}}", 'score': 0.995975, 'raw_content': None}, {'url': 'https://en.climate-data.org/europe/latvia-175/c/february-2/', 'title': 'Weather Latvia in February 2026 - Climate-Data.org', 'content': '>>Current temperature and weather forecast for Latvia. Latvia weather in ... 25 February. Broken clouds. ↓ -4/ ↑ 1 °C. ↓ 24.26/ ↑ 33.08 °F. Rainrisk 0', 'score': 0.92176014, 'raw_content': None}, {'url': 'https://eng.lsm.lv/article/weather/weather/25.02.2026-wednesday-will-be-pleasantly-sunny-and-dry-in-latvia.a636256/', 'title': 'Wednesday will be pleasantly sunny and dry in Latvia - LSM', 'content': 'There will be a light wind, and the air temperature will range from +1 to -4 degrees. In Rīga, the sky will clear up during the day, and there', 'score': 0.9147261, 'raw_content': None}, {'url': 'https://www.weather25.com/europe/latvia?page=month&month=February', 'title': 'Latvia weather in February 2026 - Weather25.com', 'content': 'The weather in Latvia in February is very cold with temperatures between 23°F and 30°F, warm clothes are a must. You can expect about 3 to 8 days of rain in', 'score': 0.8989177, 'raw_content': None}, {'url': 'https://www.predictwind.com/weather/latvia/riga/riga/february?year=2026', 'title': 'Historical Weather: Riga, Latvia (february 2026) - PredictWind', 'content': 'The weather in this month is generally cool, with breezy conditions and a dry climate. Temperature Trend (°C).', 'score': 0.8616433, 'raw_content': None}], 'response_time': 1.82, 'request_id': '4ba3fa06-a85e-45b9-8525-cf006d2af45d'}
# 📝 REMEMBER: Stored result for 'search_web'
#
# --- ITERATION 2 ---
# 🧠 REASON
# 🙌 ACT: Calling 'final_answer' with {'answer': 'The current temperature in Latvia (Riga) is about -2.7°C. Since the temperature is below 20°C, subtract 5 from the temperature, resulting in -7.7°C.', 'explanation': 'I searched for the current weather in Latvia and found that the temperature is -2.7°C. According to the task, if the temperature is above 20°C, add 5, otherwise subtract 5. Since -2.7 is below 20, I subtracted 5 to get -7.7°C.'}
# ✅ FINAL ANSWER: The current temperature in Latvia (Riga) is about -2.7°C. Since the temperature is below 20°C, subtract 5 from the temperature, resulting in -7.7°C.
#
# 📝 Explanation:
# I searched for the current weather in Latvia and found that the temperature is -2.7°C.
# According to the task, if the temperature is above 20°C, add 5, otherwise subtract 5.
# Since -2.7 is below 20, I subtracted 5 to get -7.7°C.

# %% [markdown]
# ### 🏆 Final - Exercise 6: Build a Multi-Topic Research Agent
#
# This is the **ultimate challenge!** Build an agent that can research multiple topics and compare them.
#
# **Task:** Ask your agent a question that requires **multiple web searches** and **combining** the results:
#
# > *"Compare the populations of Latvia and Lithuania. Which country has more people and by how many?"*
#
# The agent will need to:
# 1. Search for Latvia's population
# 2. Search for Lithuania's population
# 3. Use `subtract_numbers` to find the difference
# 4. Give a final comparison
#
# **Hints:**
# - Make sure `subtract_numbers` and `search_web` are both in your tools list and map
# - Use a good system instruction that tells the agent to search for each country separately
# - Set `max_iterations` high enough (e.g., 10) since multiple searches take multiple iterations

# %%
# TODO: Build a tools list and map that includes search_web AND subtract_numbers (plus the other math tools)
my_final_tools = [add_numbers, multiply_numbers, divide_numbers, search_web, final_answer]

MY_FINAL_MAP = {
     "add_numbers": add_numbers,
    "multiply_numbers": multiply_numbers,
    "divide_numbers": divide_numbers,
    "search_web": search_web}

# TODO: Ask a multi-search comparison question using react_cycle
# Think about what system_instruction and max_iterations you'll need

result = react_cycle(
    task = "Compare the populations of Latvia and Lithuania. Which country has more people and by how many?",
    tools=my_final_tools,
    tool_map=MY_FINAL_MAP,
    system_instruction="You are a helpful assistant with access to the web. search each country separately and give result precisely",
    max_iterations=10
    )
# Out:
# --- ITERATION 1 ---
# 🧠 REASON
# 🙌 ACT: Calling 'search_web' with {'query': 'current population of Latvia'}
# 👀 OBSERVE: Result = {'query': 'current population of Latvia', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.worldometers.info/world-population/latvia-population/', 'title': 'Latvia Population (2026) - Worldometer', 'content': "The current population of Latvia is 1,841,520 as of Monday, February 23, 2026, based on Worldometer's elaboration of the latest United Nations data1. Latvia", 'score': 0.99985576, 'raw_content': None}, {'url': 'https://data.who.int/countries/428', 'title': 'Latvia - WHO Data', 'content': 'Overall Population over time\u200b\u200b In Latvia, the current population is 1,882,396 as of 2023 with a projected decrease of 20% to 1,513,810 by 2050.', 'score': 0.99968004, 'raw_content': None}, {'url': 'https://countrymeters.info/en/Latvia', 'title': 'Latvia population (2026) live — Countrymeters', 'content': 'The current population of Latvia is 1762745 as of Tuesday, February 24, 2026. Population clock live, current, historical and projected population.', 'score': 0.99957937, 'raw_content': None}, {'url': 'https://stat.gov.lv/en/statistics-themes/population/population/press-releases/22900-number-population-latvia-2024', 'title': 'Latvia has a population of almost 1.86 million', 'content': 'According to the Central Statistical Bureau (CSB), population of Latvia stood at 1 million 857 thousand at the beginning of 2025.', 'score': 0.99941623, 'raw_content': None}, {'url': 'https://www.macrotrends.net/global-metrics/countries/lva/latvia/population', 'title': 'Latvia Population (1950-2025) - Macrotrends', 'content': 'Total population for Latvia in 2024 was 1,810,240, a 3.58% decline from 2023. · Total population for Latvia in 2023 was 1,877,445, a 0.1% decline from 2022.', 'score': 0.99936384, 'raw_content': None}], 'response_time': 0.79, 'request_id': 'd131994c-4178-49bd-a466-151773f38c88'}
# 📝 REMEMBER: Stored result for 'search_web'
# 🙌 ACT: Calling 'search_web' with {'query': 'current population of Lithuania'}
# 👀 OBSERVE: Result = {'query': 'current population of Lithuania', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.worldometers.info/world-population/lithuania-population/', 'title': 'Lithuania Population (2026) - Worldometer', 'content': "The current population of Lithuania is 2,811,013 as of Tuesday, February 24, 2026, based on Worldometer's elaboration of the latest United Nations data1.", 'score': 0.95250803, 'raw_content': None}, {'url': 'https://www.macrotrends.net/global-metrics/countries/ltu/lithuania/population', 'title': 'Lithuania Population (1950-2025) - Macrotrends', 'content': 'Total current population for Lithuania in 2025 was 2,668,446, a 0.9% decline from 2024. Total population for Lithuania in 2024 was 2,692,798,', 'score': 0.94339466, 'raw_content': None}, {'url': 'https://countrymeters.info/en/Lithuania', 'title': 'Lithuania population (2026) live - Countrymeters.', 'content': 'As of 1 January 2026, the population of Lithuania was estimated to be 2,483,642 people. This is a decrease of -1.63 % (-41,129 people) compared to population of', 'score': 0.9158166, 'raw_content': None}, {'url': 'https://osp.stat.gov.lt/en/lietuvos-gyventojai-2023/salies-gyventojai/gyventoju-skaicius-ir-sudetis', 'title': 'The population of Lithuania (edition 2023)', 'content': 'The estimated resident population of Lithuania amounted to 2 million 857 thousand, ie by 51.3 thousand persons more than at the beginning of 2022.', 'score': 0.8961153, 'raw_content': None}, {'url': 'https://www.statista.com/statistics/541502/total-population-of-lithuania/?srsltid=AfmBOoqdPOagVX3H-UtY3InIkfEDynJ_ynjRKW4hMs45NtVOaTu71N__', 'title': 'Total population Lithuania - Statista', 'content': 'In 2024, the total population of Lithuania stood at 2.89 million people. Between 1995 and 2024, the figure dropped by 740,000 people, though the decline', 'score': 0.8961153, 'raw_content': None}], 'response_time': 0.68, 'request_id': '7ee589ac-2351-459c-8fb2-0c1089641639'}
# 📝 REMEMBER: Stored result for 'search_web'
#
# --- ITERATION 2 ---
# 🧠 REASON
# 🙌 ACT: Calling 'multiply_numbers' with {'a': 2.8, 'b': 1000000}
# 👀 OBSERVE: Result = {'result': 2800000.0}
# 📝 REMEMBER: Stored result for 'multiply_numbers'
#
# --- ITERATION 3 ---
# 🧠 REASON
# 🙌 ACT: Calling 'multiply_numbers' with {'a': 1.85, 'b': 1000000}
# 👀 OBSERVE: Result = {'result': 1850000.0}
# 📝 REMEMBER: Stored result for 'multiply_numbers'
#
# --- ITERATION 4 ---
# 🧠 REASON
# 🙌 ACT: Calling 'add_numbers' with {'a': 2800000, 'b': -1850000}
# 👀 OBSERVE: Result = {'result': 950000}
# 📝 REMEMBER: Stored result for 'add_numbers'
#
# --- ITERATION 5 ---
# 🧠 REASON
# 🙌 ACT: Calling 'final_answer' with {'answer': "Lithuania has more people than Latvia. Lithuania's population is approximately 2.8 million, while Latvia's population is about 1.85 million. Lithuania has about 950,000 more people than Latvia.", 'explanation': "The current population of Latvia is approximately 1.85 million, while the current population of Lithuania is approximately 2.8 million. By subtracting Latvia's population from Lithuania's population, the difference is about 950,000 people."}
# ✅ FINAL ANSWER: Lithuania has more people than Latvia. Lithuania's population is approximately 2.8 million, while Latvia's population is about 1.85 million. Lithuania has about 950,000 more people than Latvia.
#
# 📝 Explanation:
# The current population of Latvia is approximately 1.85 million, while the current population of Lithuania is approximately 2.8 million.
# By subtracting Latvia's population from Lithuania's population, the difference is about 950,000 people.

# %% [markdown]
# # Final Note:
# - You have learned how AI Agents work under the hood which is the foundation of Agentic AI!
#
# - Next you will learn frameworks that make building agents and their workflows easier, like LangChain and LangGraph.
#
# - Have fun coding! 🚀
